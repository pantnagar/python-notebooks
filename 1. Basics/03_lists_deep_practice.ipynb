# %% [markdown]
# # Python Data Types Deep Practice — Lists
# ### 30 Questions, Progressive Difficulty
#
# Same rules as before: attempt first, don't peek early, run your own cell before the solution cell.
#
# ---

# %% [markdown]
# ## Part A: Creating, Indexing & Slicing (Q1-Q7)

# %% [markdown]
# **Q1** Create a list `scores = [720, 610, 800, 590, 700]`. Print the first element and the last element.

# %%
# YOUR CODE HERE
score=[720,610,800,590,700]
score[0],score[-1]
# Out:
# (720, 700)

# %% [markdown]
# **Solution 1**

# %%
scores = [720, 610, 800, 590, 700]
print(scores[0])
print(scores[-1])

# %% [markdown]
# **Q2** From `scores`, print the first 3 elements using slicing, then the last 2 elements using slicing.

# %%
# YOUR CODE HERE
print(score[:3])
print(score[-2:])
# Out:
# [720, 610, 800]
# [590, 700]

# %% [markdown]
# **Solution 2**

# %%
scores = [720, 610, 800, 590, 700]
print(scores[:3])
print(scores[-2:])
# Out:
# [720, 610, 800]
# [590, 700]

# %% [markdown]
# **Q3** Given `scores`, reverse the list using slicing (no `.reverse()` or `reversed()`).

# %%
# YOUR CODE HERE
scores[::-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 # YOUR CODE HERE
#       2 scores[::-1]
# ----> 3 new=score.reversed()
#       4 new
#
# AttributeError: 'list' object has no attribute 'reversed'

# %% [markdown]
# **Solution 3**

# %%
scores = [720, 610, 800, 590, 700]
print(scores[::-1])

# %% [markdown]
# **Q4** Create an empty list `high_risk = []`. Use `.append()` to add three scores below 650 one at a time.

# %%
# YOUR CODE HERE
high_risk=[]
high_risk.append(590)
high_risk.append(600)
high_risk
# Out:
# [590, 600]

# %% [markdown]
# **Solution 4**

# %%
high_risk = []
high_risk.append(600)
high_risk.append(590)
high_risk.append(620)
print(high_risk)

# %% [markdown]
# **Q5** Given `names = ["Alice", "Bob"]`, use `.insert()` to add `"Cara"` at index 1 (between Alice and Bob).

# %%
# YOUR CODE HERE
names=['Alice','Bob']
names.insert(1,'Cara')
print(names)
# Out:
# ['Alice', 'Cara', 'Bob']

# %% [markdown]
# **Solution 5**

# %%
names = ["Alice", "Bob"]
names.insert(1, "Cara")
print(names)

# %% [markdown]
# **Q6** Given `defaults = [1, 0, 1, 1, 0]`, check whether the value `1` exists using the `in` keyword. Then find its first index using `.index()`.

# %%
# YOUR CODE HERE
defaults=[1,0,1,1,0]
defaults.index(1)
# Out:
# 0

# %% [markdown]
# **Solution 6**

# %%
defaults = [1, 0, 1, 1, 0]
print(1 in defaults)
print(defaults.index(1))

# %% [markdown]
# **Q7** Given a nested list `transactions = [["Alice", 500], ["Bob", 1200], ["Cara", 300]]`, print just Bob's transaction amount (access the nested element directly).

# %%
# YOUR CODE HERE
transactions=[["Alice", 500], ["Bob", 1200], ["Cara", 300]]
transactions[1][1]
# Out:
# 1200

# %% [markdown]
# **Solution 7**

# %%
transactions = [["Alice", 500], ["Bob", 1200], ["Cara", 300]]
print(transactions[1][1])

# %% [markdown]
# ## Part B: Modifying Lists (Q8-Q14)

# %% [markdown]
# **Q8** Given `balances = [1000, 2000, 3000]`, update the second element to `2500` by direct index assignment.

# %%
# YOUR CODE HERE
balances=[1000,2000,3000]
balances[1]=2500
balances
# Out:
# [1000, 2500, 3000]

# %% [markdown]
# **Solution 8**

# %%
balances = [1000, 2000, 3000]
balances[1] = 2500
print(balances)

# %% [markdown]
# **Q9** Given `pending = ["loan_a", "loan_b", "loan_c"]`, remove `"loan_b"` using `.remove()`.

# %%
# YOUR CODE HERE
pending = ["loan_a", "loan_b", "loan_c"]
pending.remove('loan_b')
print(pending)
# Out:
# ['loan_a', 'loan_c']

# %% [markdown]
# **Solution 9**

# %%
pending = ["loan_a", "loan_b", "loan_c"]
pending.remove("loan_b")
print(pending)

# %% [markdown]
# **Q10** Given `queue = [10, 20, 30, 40]`, remove and print the last item using `.pop()`, then remove and print the item at index 0 using `.pop(0)`.

# %%
# YOUR CODE HERE
queue=[10,20,30,40]
queue.pop(0)
# Out:
# 10

# %% [markdown]
# **Solution 10**

# %%
queue = [10, 20, 30, 40]
last = queue.pop()
print(last, queue)
first = queue.pop(0)
print(first, queue)

# %% [markdown]
# **Q11** Given `codes = ["B", "A", "C"]`, sort it alphabetically in place using `.sort()`, then print it. Then sort `nums = [5, 2, 9, 1]` in descending order using `.sort(reverse=True)`.

# %%
# YOUR CODE HERE
codes=['B','A','C']
codes.sort()
codes
nums=[5,2,9,1]
nums.sort(reverse='TrUe')
nums
# Out:
# [9, 5, 2, 1]

# %% [markdown]
# **Solution 11**

# %%
codes = ["B", "A", "C"]
codes.sort()
print(codes)

nums = [5, 2, 9, 1]
nums.sort(reverse=True)
print(nums)

# %% [markdown]
# **Q12** Given `raw_scores = [720, 610, 800]`, create a NEW sorted list using `sorted()` without modifying the original. Print both to prove the original is unchanged.

# %%
# YOUR CODE HERE
raw_scores=[720,610,800]
new_list=sorted(raw_scores)
print(raw_scores,new_list)
# Out:
# [720, 610, 800] [610, 720, 800]

# %% [markdown]
# **Solution 12**

# %%
raw_scores = [720, 610, 800]
new_sorted = sorted(raw_scores)
print(raw_scores)
print(new_sorted)

# %% [markdown]
# **Q13** Given `combo = [1, 2, 3]` and `extra = [4, 5, 6]`, combine them into one list two ways: using `+` and using `.extend()`.

# %%
# YOUR CODE HERE
combo=[1,2,3]
extra=[4,5,6]
combo.extend(extra)
combo
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **Solution 13**

# %%
combo = [1, 2, 3]
extra = [4, 5, 6]
combined_plus = combo + extra
print(combined_plus)

combo2 = [1, 2, 3]
combo2.extend(extra)
print(combo2)

# %% [markdown]
# **Q14** Given `duplicate_ids = [101, 102, 101, 103, 102]`, remove duplicates while keeping only unique values (order doesn't matter — use a set conversion).

# %%
# YOUR CODE HERE
duplicate_ids = [101, 102, 101, 103, 102]
unique=list(set(duplicate_ids))
unique
# Out:
# [101, 102, 103]

# %% [markdown]
# **Solution 14**

# %%
duplicate_ids = [101, 102, 101, 103, 102]
unique_ids = list(set(duplicate_ids))
print(unique_ids)

# %% [markdown]
# ## Part C: Looping & Comprehensions (Q15-Q22)

# %% [markdown]
# **Q15** Given `scores = [720, 610, 800, 590, 700]`, loop through and print only the scores above 650.

# %%
# YOUR CODE HERE
score
for i in score:
    if i>650:
        print(i)
# Out:
# 720
# 800
# 700

# %% [markdown]
# **Solution 15**

# %%
scores = [720, 610, 800, 590, 700]
for s in scores:
    if s > 650:
        print(s)

# %% [markdown]
# **Q16** Rewrite Q15 as a single list comprehension that returns a list of scores above 650 (instead of printing one by one).

# %%
# YOUR CODE HERE
[i for i in score if i>650]
# Out:
# [720, 800, 700]

# %% [markdown]
# **Solution 16**

# %%
scores = [720, 610, 800, 590, 700]
above_650 = [s for s in scores if s > 650]
print(above_650)
# Out:
# [720, 800, 700]

# %% [markdown]
# **Q17** Given `scores`, use a list comprehension to create a list of `"Pass"`/`"Fail"` labels: `"Pass"` if score >= 650, else `"Fail"`.

# %%
# YOUR CODE HERE
['Pass' if s>=650 else 'Fail' for s in scores]
# Out:
# ['Pass', 'Fail', 'Pass', 'Fail', 'Pass']

# %% [markdown]
# **Solution 17**

# %%
scores = [720, 610, 800, 590, 700]
labels = ["Pass" if s >= 650 else "Fail" for s in scores]
print(labels)

# %% [markdown]
# **Q18** Given `scores`, use `enumerate()` in a loop to print each score along with its position, e.g. `"Customer 0: 720"`.

# %%
# YOUR CODE HERE
for i,s in enumerate(scores):
    print(f'Customer {i}:{s}')
# Out:
# Customer 0:720
# Customer 1:610
# Customer 2:800
# Customer 3:590
# Customer 4:700

# %% [markdown]
# **Solution 18**

# %%
scores = [720, 610, 800, 590, 700]
for i, s in enumerate(scores):
    print(f"Customer {i}: {s}")

# %% [markdown]
# **Q19** Given ``names = ["Alice", "Bob", "Cara"]` and `scores = [720, 610, 800]``, use `zip()` to loop through both together and print `"Alice: 720"` style output.

# %%
# YOUR CODE HERE
names = ["Alice", "Bob", "Cara"]
scores = [720, 610, 800]
zip(names,scores)
for n,s in zip(names,scores):
    print(f'name is {n} and score is {s}')
# Out:
# name is Alice and score is 720
# name is Bob and score is 610
# name is Cara and score is 800

# %% [markdown]
# **Solution 19**

# %%
names = ["Alice", "Bob", "Cara"]
scores = [720, 610, 800]
for n, s in zip(names, scores):
    print(f"{n}: {s}")

# %% [markdown]
# **Q20** Using the same `names` and `scores`, build a dictionary `{name: score}` using a single line combining `zip()` and `dict()`.

# %%
# YOUR CODE HERE
new_dic=dict(zip(names,scores))
new_dic
# Out:
# {'Alice': 720, 'Bob': 610, 'Cara': 800}

# %% [markdown]
# **Solution 20**

# %%
names = ["Alice", "Bob", "Cara"]
scores = [720, 610, 800]
name_score = dict(zip(names, scores))
print(name_score)

# %% [markdown]
# **Q21** Given `amounts = [100, -50, 200, -30, 400]` (negative = refund), use a list comprehension to get only the positive charges.

# %%
# YOUR CODE 
amounts=[100,-50,200,-30,400]
[amt for amt in amounts if amt>0]
# Out:
# [100, 200, 400]

# %% [markdown]
# **Solution 21**

# %%
amounts = [100, -50, 200, -30, 400]
charges = [a for a in amounts if a > 0]
print(charges)

# %% [markdown]
# **Q22** Given `matrix = [[1,2,3],[4,5,6],[7,8,9]]` (rows = customers, columns = monthly payments), use a nested list comprehension to flatten it into a single list.

# %%
# YOUR CODE HERE
matrix=[[1,2,3],[4,5,6],[7,8,9]]
[val for row in matrix for val in row]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# **Solution 22**

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
flat = [val for row in matrix for val in row]
print(flat)

# %% [markdown]
# ## Part D: Aggregation & Built-ins (Q23-Q27)

# %% [markdown]
# **Q23** Given `balances = [1200, 3400, 500, 8900, 200]`, find the `sum()`, `max()`, `min()`, and average (compute manually) in one cell.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 23**

# %%
balances = [1200, 3400, 500, 8900, 200]
total = sum(balances)
highest = max(balances)
lowest = min(balances)
average = total / len(balances)
print(total, highest, lowest, average)

# %% [markdown]
# **Q24** Given `defaults = [1, 0, 1, 1, 0, 0, 1]` (1 = defaulted), calculate the default rate as a percentage using `sum()` and `len()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 24**

# %%
defaults = [1, 0, 1, 1, 0, 0, 1]
default_rate = sum(defaults) / len(defaults) * 100
print(f"{default_rate:.2f}%")

# %% [markdown]
# **Q25** Given `scores = [720, 610, 800, 590, 700]`, use `sorted()` with `reverse=True` to get the top 3 scores using slicing.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 25**

# %%
scores = [720, 610, 800, 590, 700]
top_3 = sorted(scores, reverse=True)[:3]
print(top_3)

# %% [markdown]
# **Q26** Given `all_scores = [720, 610, 800, 590, 700, 650, 680]`, use `any()` to check if ANY score is below 600, and `all()` to check if ALL scores are above 500.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 26**

# %%
all_scores = [720, 610, 800, 590, 700, 650, 680]
print(any(s < 600 for s in all_scores))
print(all(s > 500 for s in all_scores))

# %% [markdown]
# **Q27** Given `risk_levels = ["Low", "High", "Medium", "High", "Low", "High"]`, count how many times `"High"` appears using `.count()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 27**

# %%
risk_levels = ["Low", "High", "Medium", "High", "Low", "High"]
print(risk_levels.count("High"))

# %% [markdown]
# ## Part E: Mini Challenges (Q28-Q30)

# %% [markdown]
# **Q28** Given customer records as a list of tuples:
# ```python
# records = [("Alice", 720, 15000), ("Bob", 610, 8000), ("Cara", 800, 22000)]
# ```
# Loop through and print a formatted line for each: name, risk category (>=750 Low, >=650 Medium, else High), and balance formatted as currency.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 28**

# %%
records = [("Alice", 720, 15000), ("Bob", 610, 8000), ("Cara", 800, 22000)]

for name, score, balance in records:
    if score >= 750:
        risk = "Low"
    elif score >= 650:
        risk = "Medium"
    else:
        risk = "High"
    print(f"{name}: {risk} Risk, Balance: ${balance:,.2f}")

# %% [markdown]
# **Q29** Given `records` from Q28, build a list comprehension that returns only the names of customers with "High" risk (score < 650).

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 29**

# %%
records = [("Alice", 720, 15000), ("Bob", 610, 8000), ("Cara", 800, 22000)]
high_risk_names = [name for name, score, balance in records if score < 650]
print(high_risk_names)

# %% [markdown]
# **Q30** Given two lists representing this month's and last month's defaulted customer IDs:
# ```python
# this_month = [101, 102, 105, 107]
# last_month = [102, 103, 105]
# ```
# Find: (a) customers who defaulted in both months, (b) customers who are NEW defaulters this month (in this_month but not last_month). Use set operations.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution 30**

# %%
this_month = [101, 102, 105, 107]
last_month = [102, 103, 105]

both_months = set(this_month) & set(last_month)
new_defaulters = set(this_month) - set(last_month)

print("Defaulted both months:", both_months)
print("New defaulters:", new_defaulters)

# %% [markdown]
# ---
# ## Checkpoint
#
# 30 questions across indexing/slicing, modifying, looping/comprehensions, aggregation, and mini real-world challenges combining tuples, dicts, and sets with lists.
#
# When you're comfortable with lists, say the word and I'll build the next one: **Dictionaries deep practice** (this one matters a lot for pandas later, since rows/records map naturally to dicts).
