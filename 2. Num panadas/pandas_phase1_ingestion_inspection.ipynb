# %% [markdown]
# # Pandas — Phase 1: Data Ingestion & Initial Inspection
# ### Credit Card Risk Analysis Track
#
# **Topics in this phase:**
# 1. Loading Data — `pd.read_csv`, `pd.read_excel`
# 2. Structural Overview — `df.shape`, `df.info()`, `df.dtypes`
# 3. Previewing Records — `df.head()`, `df.tail()`, `df.sample()`
# 4. Descriptive Statistics — `df.describe()`
#
# **Dataset:** `loan_applications.csv` / `loan_applications.xlsx` — 500 synthetic historical loan applications (income, credit score, loan amount, employment status, loan outcome, etc.), including some realistic messiness like missing values. **Place both files in the same folder as this notebook** before running it.
#
# **How to use this notebook:**
# - Each question has a `YOUR CODE HERE` cell — attempt it first.
# - The `Solution` cell right after shows one correct approach — compare, don't just copy.
# - All solutions were run against the actual dataset before this notebook was assembled.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
print(pd.__version__)

# %% [markdown]
# ## Topic 1: Loading Data
#
# Reading data in correctly — right file, right dtypes, right subset — saves headaches later.

# %% [markdown]
# **Q1.** Read `loan_applications.csv` into a DataFrame called `df`. Print its type and `.shape`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
df = pd.read_csv("loan_applications.csv")
print(type(df), df.shape)

# %% [markdown]
# **Q2.** Re-read the CSV into `df_dated`, this time telling pandas to parse the `application_date` column as actual dates using `parse_dates`. Print that column's dtype to confirm it's now a datetime, not a plain string.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
df_dated = pd.read_csv("loan_applications.csv", parse_dates=["application_date"])
print(df_dated["application_date"].dtype)

# %% [markdown]
# **Q3.** Read `loan_applications.xlsx` into `df_excel` using `pd.read_excel`, specifying `sheet_name="Applications"`. Print its shape.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
df_excel = pd.read_excel("loan_applications.xlsx", sheet_name="Applications")
print(df_excel.shape)

# %% [markdown]
# **Q4.** Read the CSV again into `df_idx`, this time using `application_id` as the index (`index_col="application_id"`) instead of a default integer index. Print the index name and the first 3 index values.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
df_idx = pd.read_csv("loan_applications.csv", index_col="application_id")
print(df_idx.index.name, df_idx.index[:3].tolist())

# %% [markdown]
# **Q5.** You don't always need every column. Read only `application_id`, `credit_score`, and `loan_amount` from the CSV into `df_subset` using the `usecols` parameter. Print its columns.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
df_subset = pd.read_csv("loan_applications.csv", usecols=["application_id", "credit_score", "loan_amount"])
print(df_subset.columns.tolist())

# %% [markdown]
# ## Topic 2: Structural Overview
#
# Run this setup cell first — from here on, `df` has dates parsed correctly:

# %%
df = pd.read_csv("loan_applications.csv", parse_dates=["application_date"])
print(df.shape)

# %% [markdown]
# **Q6.** Unpack `df.shape` into `num_rows` and `num_cols` and print both.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
num_rows, num_cols = df.shape
print(num_rows, num_cols)

# %% [markdown]
# **Q7.** Get the list of column names as `column_names` (use `.columns.tolist()`).

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
column_names = df.columns.tolist()
print(column_names)

# %% [markdown]
# **Q8.** Print `df.dtypes` to see every column's data type. Which columns are numeric, which are text (`object`), and which is the datetime you parsed in Topic 1?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
dtypes = df.dtypes
print(dtypes)

# %% [markdown]
# **Q9.** Get just the numeric column names into `numeric_cols` using `df.select_dtypes(include=np.number)`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
print(numeric_cols)

# %% [markdown]
# **Q10.** Call `df.info()`. Unlike most pandas methods, it **prints directly and returns `None`** — don't try to assign its result to a variable. Look at the output: which columns have fewer non-null values than the total row count? That's your first clue about missing data.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
df.info()

# %% [markdown]
# **Q11.** Compute `memory_bytes`, the total memory usage of `df` in bytes, using `df.memory_usage(deep=True).sum()`. (`deep=True` matters for accurate sizing of text columns.)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
memory_bytes = df.memory_usage(deep=True).sum()
print(memory_bytes)

# %% [markdown]
# ## Topic 3: Previewing Records
#
# Never trust a dataset you haven't looked at.

# %% [markdown]
# **Q12.** Get the first 5 rows of `df` into `first_5` using `.head()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
first_5 = df.head()
print(first_5)

# %% [markdown]
# **Q13.** Get the last 3 rows into `last_3` using `.tail(3)`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
last_3 = df.tail(3)
print(last_3)

# %% [markdown]
# **Q14.** Get 5 random rows into `random_5` using `.sample()`, passing `random_state=42` so the "random" selection is reproducible.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
random_5 = df.sample(5, random_state=42)
print(random_5)

# %% [markdown]
# **Q15.** Preview just the first 10 values of the `employment_status` column into `first_col_values` (select the column, then chain `.head(10)`).

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
first_col_values = df["employment_status"].head(10)
print(first_col_values.tolist())

# %% [markdown]
# **Q16.** Filter `df` down to only rows where `loan_status` is `"Denied"`, then preview the first 5 of those into `denied_preview`. (This is a sneak peek at filtering — you'll cover it properly in a later phase.)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
denied_preview = df[df["loan_status"] == "Denied"].head()
print(denied_preview[["application_id", "loan_status"]])

# %% [markdown]
# **Q17.** Sample 10% of all rows into `random_10pct` using `.sample(frac=0.1, random_state=7)`. Print its shape to confirm it's roughly 10% of the dataset.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
random_10pct = df.sample(frac=0.1, random_state=7)
print(random_10pct.shape)

# %% [markdown]
# ## Topic 4: Descriptive Statistics
#
# `df.describe()` is usually the very next thing you run after `.info()` — it turns raw numbers into a shape you can reason about.

# %% [markdown]
# **Q18.** Run `df.describe()` and store it as `summary`. Look at `loan_amount` and `credit_score` — do the min/max values look plausible for a loan portfolio?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
summary = df.describe()
print(summary)

# %% [markdown]
# **Q19.** Get summary statistics for just the `loan_amount` column into `loan_amount_stats` (you can call `.describe()` directly on a single column, not just the whole DataFrame).

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
loan_amount_stats = df["loan_amount"].describe()
print(loan_amount_stats)

# %% [markdown]
# **Q20.** Compute `avg_credit_score`, the mean of the `credit_score` column, directly with `.mean()` (note: this column has some missing values — pandas' `.mean()` skips them automatically).

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
avg_credit_score = df["credit_score"].mean()
print(avg_credit_score)

# %% [markdown]
# **Q21.** Compute `median_income`, the median of `annual_income`, using `.median()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
median_income = df["annual_income"].median()
print(median_income)

# %% [markdown]
# **Q22.** Compute `loan_amount_std`, the standard deviation of `loan_amount`, using `.std()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
loan_amount_std = df["loan_amount"].std()
print(loan_amount_std)

# %% [markdown]
# **Q23.** By default, `.describe()` only summarizes numeric columns. Run it with `include="all"` into `full_summary_incl_categorical` so text columns like `loan_status` show up too (with `count`, `unique`, `top`, `freq` instead of mean/std).

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
full_summary_incl_categorical = df.describe(include="all")
print(full_summary_incl_categorical)

# %% [markdown]
# **Q24.** Compute `credit_score_range`, the difference between the max and min `credit_score` in the dataset, using `.max()` and `.min()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
credit_score_range = df["credit_score"].max() - df["credit_score"].min()
print(credit_score_range)

# %% [markdown]
# **Q25.** Get `status_counts`: how many applications fall into each `loan_status` category, using `.value_counts()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
status_counts = df["loan_status"].value_counts()
print(status_counts)

# %% [markdown]
# **Q26.** Find the full row for the application with the single **largest** `loan_amount`, store it as `highest_loan_row`. (Hint: `.idxmax()` gives you the *index label* of the max value, which you can then feed into `.loc[]`.)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Solution**

# %%
highest_loan_row = df.loc[df["loan_amount"].idxmax()]
print(highest_loan_row)

# %% [markdown]
# ## ✅ Checkpoint
#
# **What you covered:**
# - Loading data: `pd.read_csv`, `pd.read_excel`, `parse_dates`, `index_col`, `usecols`
# - Structural overview: `.shape`, `.columns`, `.dtypes`, `.select_dtypes()`, `.info()`, `.memory_usage()`
# - Previewing records: `.head()`, `.tail()`, `.sample()` (with `random_state` for reproducibility and `frac` for percentage-based sampling)
# - Descriptive statistics: `.describe()` (numeric and `include="all"`), `.mean()`, `.median()`, `.std()`, `.value_counts()`, `.idxmax()`
#
# **Why it matters for the project:** this is the first thing you do with *any* new dataset — before cleaning, before analysis, before modeling. You already noticed `credit_score` and `annual_income` have missing values in `.info()` and `.describe()` — that's exactly the kind of thing Phase 2 (Data Cleaning) will fix properly.
#
# **What's next:** Phase 2, whenever you're ready — let me know the topics you want covered.
